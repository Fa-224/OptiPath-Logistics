# %%
# Generate synthetic data
import pandas as pd
import numpy as np

np.random.seed(42)
df = pd.DataFrame({
    'Latitude': np.random.uniform(20, 30, 1000),
    'Longitude': np.random.uniform(40, 50, 1000)
})

# Apply K-Means
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

X = df[['Latitude', 'Longitude']]
kmeans = KMeans(n_clusters=5, random_state=42)
df['Cluster'] = kmeans.fit_predict(X)

# Show sample
print(df.head())

# Plot clusters
plt.figure(figsize=(8,6))
plt.scatter(df['Longitude'], df['Latitude'], c=df['Cluster'], s=10)

# Plot centroids
centers = kmeans.cluster_centers_
plt.scatter(centers[:,1], centers[:,0], s=200, marker='X')

plt.title('K-Means Clustering')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()
# Out:
#     Latitude  Longitude  Cluster
# 0  23.745401  41.851329        0
# 1  29.507143  45.419009        1
# 2  27.319939  48.729458        1
# 3  25.986585  47.322249        1
# 4  21.560186  48.065611        4
